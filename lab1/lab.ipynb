# %%
def eratosthenes(N):    
    a = [i for i in range(1, N+1)] 
    b = []
    num=2 
    i=0 
    a.remove(1) 
    
    while num < a[-1]: 
        while len(a) > i:
            if a[i]%num == 0 and a[i]!= num: 
                b.append(a[i]) 
                a.pop(i) 
            i+=1 
        i=0 
 
        
        for j in range(len(a)):
            if a[j] > num:
                num = a[j]
                break
 
    return b

# %%
import time
import memory_profiler

yAxisMemory = []
yAxisTime = []
xAxis = []

i=0
k=10000
while i < 50:
    xAxis.append(i)
    m1 = memory_profiler.memory_usage()
    
    start_time = time.time()
    eratosthenes(k)
    yAxisTime.append(time.time() - start_time)
    m2=memory_profiler.memory_usage() 
    yAxisMemory.append(m2[0] - m1[0])
    print(f"It took {yAxisTime[i]} Secs and {yAxisMemory[i]} Mb ")

    i=i+1
    
input

# %matplotlib notebook
import matplotlib.pyplot as plt
plt.subplot(2, 2, 1)
plt.plot(xAxis, yAxisTime)

plt.subplot(2, 2, 3)
plt.plot(xAxis, yAxisMemory)
# Out:
# It took 0.3136899471282959 Secs and 0.05078125 Mb
# It took 0.29872989654541016 Secs and 0.00390625 Mb
# It took 0.29170989990234375 Secs and 0.0 Mb
# It took 0.29871582984924316 Secs and 0.0 Mb
# It took 0.30072927474975586 Secs and 0.0 Mb
# It took 0.29706883430480957 Secs and 0.0 Mb
# It took 0.29514241218566895 Secs and 0.0 Mb
# It took 0.2917137145996094 Secs and 0.0 Mb
# It took 0.2977280616760254 Secs and 0.0 Mb
# It took 0.2927663326263428 Secs and 0.0 Mb
# It took 0.29015445709228516 Secs and 0.0 Mb
# It took 0.2911067008972168 Secs and 0.0 Mb
# It took 0.2890589237213135 Secs and 0.0 Mb
# It took 0.29581689834594727 Secs and 0.0 Mb
# It took 0.2947373390197754 Secs and 0.0 Mb
# It took 0.29672932624816895 Secs and 0.0 Mb
# It took 0.28774094581604004 Secs and 0.25390625 Mb
# It took 0.29473328590393066 Secs and 0.20703125 Mb
# It took 0.2967078685760498 Secs and 0.0 Mb
# It took 0.30072522163391113 Secs and 0.0 Mb
# It took 0.2927117347717285 Secs and 0.0 Mb
# It took 0.29873228073120117 Secs and 0.0 Mb
# It took 0.3010709285736084 Secs and 0.0 Mb
# It took 0.30569958686828613 Secs and 0.0 Mb
# It took 0.2887141704559326 Secs and 0.0 Mb
# It took 0.29273295402526855 Secs and 0.0 Mb
# It took 0.2947061061859131 Secs and 0.0 Mb
# It took 0.29514074325561523 Secs and 0.0 Mb
# It took 0.29873108863830566 Secs and 0.0 Mb
# It took 0.2897369861602783 Secs and 0.0 Mb
# It took 0.29673171043395996 Secs and 0.0 Mb
# It took 0.29473352432250977 Secs and 0.0 Mb
# It took 0.3027024269104004 Secs and 0.0 Mb
# It took 0.28873634338378906 Secs and 0.0 Mb
# It took 0.299694299697876 Secs and 0.0 Mb
# It took 0.290738582611084 Secs and 0.0 Mb
# It took 0.3037228584289551 Secs and 0.0 Mb
# It took 0.29173851013183594 Secs and 0.0 Mb
# It took 0.29473066329956055 Secs and 0.0 Mb
# It took 0.29285597801208496 Secs and 0.0 Mb
# It took 0.2906651496887207 Secs and 0.0 Mb
# It took 0.2939136028289795 Secs and 0.0 Mb
# It took 0.2947239875793457 Secs and 0.0 Mb
# It took 0.29772281646728516 Secs and 0.0 Mb
# It took 0.29770946502685547 Secs and 0.0 Mb
# It took 0.28873538970947266 Secs and 0.0 Mb
# It took 0.3027181625366211 Secs and 0.0 Mb
# It took 0.29672908782958984 Secs and 0.0 Mb
# It took 0.29770922660827637 Secs and 0.0 Mb
# It took 0.2997288703918457 Secs and 0.0 Mb
# <img src="data:image/png;base64,..." width="640">
